# %% [markdown]
# # Chapter 1. gpu 사용가능한 환경인지 확인하기!

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# # Chapter 2. 객체 탐지 이론을 배우기전에 필요한 라이브러리 설치하기

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Chapter 3. 객체 탐지란?

# %% [markdown]
# ![객체 탐지 예시 사진](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FqtG0u%2FbtqNiVSdEwu%2FFsDObIYSewKaFpyR1nGQA0%2Fimg.jpg)

# %% [markdown]
# ##### 인공지능으로 학습한 모델을 통해 객체의 클라스(고양이, 개, 말)을 분류하고 객체의 위치까지 box로 표시하는 것이 객체탐지

# %% [markdown]
# ##### 1. 작물재배에서의 병충해를 탐지하거나

# %% [markdown]
# ![병충해탐지](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRaC9I4Y5Qd_ntwV2Wn6aRawUcLbmEHCzzhZA&s)

# %% [markdown]
# ##### 2. 자율주행 과정에서의 안전을 위해 사용하거나

# %% [markdown]
# ![자율주행 자동차](https://blog.kakaocdn.net/dna/bBxjO6/btqAMka889E/AAAAAAAAAAAAAAAAAAAAADoBS4SY7v35C6YDAzOb6mPWvriSQpREGcPu_k1vc4rG/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1780239599&allow_ip=&allow_referer=&signature=3nIwc%2FkqqkLw%2Fg66AdHZa7py9q8%3D)

# %% [markdown]
# ##### 3. 범죄를 막기위한 이상행동을 탐지가능합니다.

# %% [markdown]
# ![이상행동탐지](https://velog.velcdn.com/images/dangdang/post/c5787d3f-974f-46d9-a8b8-d77fccc590e8/image.png)

# %% [markdown]
# # Chapter 4. 객체 탐지 실습 첫번째!

# %% [markdown]
# ##### ultralytics라는 라이브러리를 통해 쉽게 객체 탐지를 해보자

# %% [markdown]
# ![울트래릭틱스](https://cdn.prod.website-files.com/680a070c3b99253410dd3df5/680a070c3b99253410dd487b_65bf057ca86d0b658cd7e83c_65416e2dd2ffd021e7954705_Discord%252520Discovery_Invite%252520Splash%252520Image.webp)

# %% [markdown]
# ##### 객체 탐지 결과를 글(text)로 출력하기

# %% [markdown]
# ##### cpu로 인공지능 모델을 돌려서 예측하는 속도와 GPU로 예측하는 속도도 한번 비교해봅시다.

# %%
from ultralytics import YOLO

model = YOLO("models/yolov8n.pt")
source = "https://m.health.chosun.com/site/data/img_dir/2022/07/28/2022072802389_0.jpg"  # 사진을 모델한테 예측하라고 입력하기
results = model(source)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# ...
# image 1/1 /content/2022072802389_0.jpg: 416x640 1 cat, 1 dog, 72.4ms
# Speed: 5.5ms preprocess, 72.4ms inference, 38.3ms postprocess per image at shape (1, 3, 416, 640)

# %% [markdown]
# ##### 객체 탐지 결과를 시각화해서 저장해보자

# %% [markdown]
# ##### predict 라는 함수 속 다양한 매개변수들을 이해해보자

# %%
from ultralytics import YOLO

model = YOLO("models/yolov8n.pt")
model.predict("https://m.health.chosun.com/site/data/img_dir/2022/07/28/2022072802389_0.jpg", save=True, show_labels=False, imgsz=320, conf=0.5) # 사진을 입력하기
# Out:
# Found https://m.health.chosun.com/site/data/img_dir/2022/07/28/2022072802389_0.jpg locally at 2022072802389_0.jpg
# image 1/1 /content/2022072802389_0.jpg: 224x320 1 cat, 1 dog, 69.2ms
# Speed: 6.4ms preprocess, 69.2ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %% [markdown]
# ![모델들](https://raw.githubusercontent.com/ultralytics/assets/refs/heads/main/yolo/performance-comparison.png)

# %% [markdown]
# ![coco_dataset](https://i.ytimg.com/vi/ARE242Hb4-Q/hqdefault.jpg)

# %% [markdown]
# # Chapter 5. 나만의 객체 탐지 모델을 만들고 싶다!

# %% [markdown]
# ##### 나만의 탐지 모델을 만들기 위해서는 모델이란 친구에게 내가 탐지하고 싶은 객체(개, 고양이 등)정보와
# ##### 위치 정보(box)를 알려주고 이 객체만 탐지하게 해야만 활용방안이 많아집니다.

# %% [markdown]
# ##### 객체 (클래스)정보와 위치 정보를 모델에게 알려주기 위한 과정은 라벨링(Labeling)이라고 합니다.

# %% [markdown]
# ![labeling](https://miro.medium.com/1*z9iwHZQJcQRsC1SZ0-SN_w.png)

# %% [markdown]
# ##### 간편하게 라벨링을 하는 웹 사이트! Roboflow!
# ##### https://roboflow.com/

# %% [markdown]
# ![roboflow](https://storage.ghost.io/c/2c/8d/2c8d8c0d-1c15-4b6d-825e-02b78d61d40a/content/images/2026/02/img-blog-getting-started-v3.png)

# %% [markdown]
# ##### 로보플로우란 사이트에서 라벨링한 이미지와 정보를 가져오기

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="GRAkD2NSvuGnUfmYJ0Ya")
project = rf.workspace("project-pagyk").project("rock-paper-scissors")
dataset = project.version(1).download("coco")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 141.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# ...

# %%
# 만약 zip파일이 압축이 안 풀어져 있다면
import zipfile

with zipfile.ZipFile("roboflow.zip", 'r') as zip_ref:
    zip_ref.extractall(".")

import os
os.remove("roboflow.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4968/3028277962.py in <cell line: 0>()
#       2 import zipfile
#       3
# ----> 4 with zipfile.ZipFile("roboflow.zip", 'r') as zip_ref:
#       5     zip_ref.extractall(".")
#       6
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'roboflow.zip'

# %% [markdown]
# ##### 나만의 라벨링한 커스텀 데이터로 인공지능 모델을 학습하는 코드 시작

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(data='data.yaml', epochs=20,lr0=0.01)
# Out:
# ...
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ##### 직접 만든 가위바위보 탐지 모델을 사용해보기

# %%
from ultralytics import YOLO
import cv2
import requests
import numpy as np
from google.colab.patches import cv2_imshow

# ==========================================
# 1. 모델 불러오기
# ==========================================
model = YOLO('/content/runs/detect/train-3/weights/best.pt')

# ==========================================
# 2. 이미지 URL
# ==========================================
image_url = 'https://www.asianscientist.com/wp-content/uploads/bfi_thumb/20170815-rock-scissors-pixabay-34f3h8kx0ucail5dbcp8n4.jpg'

# ==========================================
# 3. 이미지 다운로드
# ==========================================
response = requests.get(image_url)

image_array = np.asarray(bytearray(response.content), dtype=np.uint8)

image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)

if image is None:
    print("이미지를 불러올 수 없습니다.")
    exit()

# ==========================================
# 4. YOLO 예측
# ==========================================
results = model.predict(
    source=image,
    conf=0.1,
    iou=0.5,
    imgsz=640,
    verbose=False
)

# ==========================================
# 5. 탐지 결과 시각화
# ==========================================
annotated_image = results[0].plot()

# ==========================================
# 6. 출력
# ==========================================
cv2_imshow(annotated_image)
